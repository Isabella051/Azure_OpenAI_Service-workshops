# %% [markdown]
# # Description:
#   - This example shows how to retrieve data from Azure SQL DB by using Open AI GPT.
#   - Asking questions in plain english that gets "translated" by GPT into SQL.
#   - Using Langchain SQLDatabaseChain
#
# ## Requirements:
#   - For this laboratory you need the Microsoft ODBC 18 driver installed in your system:
#     - Windows: https://learn.microsoft.com/en-us/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver16#download-for-windows
#     - Mac: https://learn.microsoft.com/en-us/sql/connect/odbc/linux-mac/install-microsoft-odbc-driver-sql-server-macos?view=sql-server-ver15#microsoft-odbc-18
#     - Linux: https://learn.microsoft.com/en-us/sql/connect/odbc/linux-mac/installing-the-microsoft-odbc-driver-for-sql-server?view=sql-server-ver15&tabs=ubuntu18-install%2Cubuntu17-install%2Cdebian8-install%2Credhat7-13-install%2Crhel7-offline#18
#
# ## Sample questions you can ask:
#   - List the tables in the database
#   - How many products are in the Adventure Works database?
#   - How many Products are color black?
#   - How many SalesOrderDetail are for the Product AWC Logo Cap ?
#   - List the top 10 most expensive products
#
# ## For more information about Langchain agent toolkits, see:
#   https://python.langchain.com/docs/modules/agents/tools/toolkits

# %%
from langchain_openai import AzureChatOpenAI
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine, text
from sqlalchemy.engine import URL
from langchain_community.utilities.sql_database import SQLDatabase
from langchain_community.agent_toolkits import create_sql_agent, SQLDatabaseToolkit
from langchain.chains import create_sql_query_chain

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_DEPLOYMENT_ENDPOINT = os.getenv("OPENAI_DEPLOYMENT_ENDPOINT")
OPENAI_GPT35_DEPLOYMENT_NAME = os.getenv("OPENAI_GPT35_DEPLOYMENT_NAME")
OPENAI_GPT4_DEPLOYMENT_NAME = os.getenv("OPENAI_GPT4_DEPLOYMENT_NAME")

SQL_SERVER = os.getenv("SQL_SERVER")
SQL_USER = os.getenv("SQL_USER")
SQL_PWD = os.getenv("SQL_PWD")
SQL_DBNAME = os.getenv("SQL_DBNAME")

# %%
def init_llm(model=OPENAI_GPT35_DEPLOYMENT_NAME,
             deployment_name=OPENAI_GPT35_DEPLOYMENT_NAME,
             openai_api_version="2024-02-15-preview",
             temperature=0,
             max_tokens=400
             ):

    llm = AzureChatOpenAI(deployment_name=deployment_name,
                            model=model,
                            openai_api_version=openai_api_version,
                            azure_endpoint=OPENAI_DEPLOYMENT_ENDPOINT,
                            temperature=temperature,
                            max_tokens=max_tokens
                            )
    return llm

llm = init_llm()

# %%
# Configuration for the database connection
db_config = {
    'drivername': 'mssql+pyodbc',
    'username': SQL_USER + '@' + SQL_SERVER,
    'password': SQL_PWD,
    'host': SQL_SERVER,
    'port': 1433,
    'database': SQL_DBNAME,
    'query': {'driver': 'ODBC Driver 18 for SQL Server'},
}

# Create a URL object for connecting to the database
db_url = URL.create(**db_config)

# Connect to the Azure SQL Database using the URL string
engine = create_engine(db_url)

# Test the connection using the SQLAlchemy 2.0 execution style
with engine.connect() as conn:
    try:
        # Use the text() construct for safer SQL execution
        result = conn.execute(text("SELECT @@VERSION"))
        version = result.fetchone()
        print("Connection successful!")
        print(version)
    except Exception as e:
        print(e)

db = SQLDatabase.from_uri(db_url, schema='SalesLT')
# Out:
# Connection successful!
# ('Microsoft SQL Azure (RTM) - 12.0.2000.8 \n\tAug  6 2025 10:21:16 \n\tCopyright (C) 2025 Microsoft Corporation\n',)
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'StateProvince'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'CountryRegion'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'NameStyle' of column 'NameStyle'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'FirstName'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'MiddleName'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'LastName'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Phone' of column 'Phone'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'AddressType'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Name' of column 'Name'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'Flag' of column 'OnlineOrderFlag'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'OrderNumber' of column 'PurchaseOrderNumber'
#   self._metadata.reflect(
# /opt/anaconda3/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:134: SAWarning: Did not recognize type 'AccountNumber' of column 'AccountNumber'
#   self._metadata.reflect(

# %%
chain = create_sql_query_chain(llm, db)

# %%
query = chain.invoke({"question":"How many products are in the Adventure Works database using SalesLT schema?"})
print("Query generated by OpenAI: " + query)
# Out:
# Query generated by OpenAI: SELECT COUNT([ProductID]) AS TotalProducts
# FROM [SalesLT].[Product]

# %%
db.run(query)
# Out:
# '[(295,)]'

# %%
query = chain.invoke({"question":"How many Products are color black?"})
print("Query generated by OpenAI: " + query)
# Out:
# Query generated by OpenAI: SELECT COUNT(*) AS BlackProductCount
# FROM [SalesLT].[Product]
# WHERE [Color] = 'Black'

# %%
db.run(query)
# Out:
# '[(89,)]'

# %%
query = chain.invoke({"question":"How many SalesOrderDetail are for the Product AWC Logo Cap ?"})
print("Query generated by OpenAI: " + query)
# Out:
# Query generated by OpenAI: SELECT COUNT(*) AS NumberOfSalesOrderDetail
# FROM [SalesLT].[SalesOrderDetail] sod
# JOIN [SalesLT].[Product] p ON sod.ProductID = p.ProductID
# WHERE p.ProductNumber = 'AWC-CAP-W01'

# %%
db.run(query)
# Out:
# '[(0,)]'

# %% [markdown]
# ### Let's work with Agents to give some reasoning capabilities to our chatbot.
# GPT 4 is mandatory to run this section. GPT3.5 will make mistakes.

# %%
def init_llm(model=OPENAI_GPT4_DEPLOYMENT_NAME,
             deployment_name=OPENAI_GPT4_DEPLOYMENT_NAME,
             openai_api_version="2024-02-15-preview",
             temperature=0,
             max_tokens=400
             ):

    llm = AzureChatOpenAI(deployment_name=deployment_name,
                            model=model,
                            api_key=OPENAI_API_KEY,
                            openai_api_version=openai_api_version,
                            azure_endpoint=OPENAI_DEPLOYMENT_ENDPOINT,
                            temperature=temperature,
                            max_tokens=max_tokens
                            )
    return llm

llm = init_llm()

# %%
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

agent_executor = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    top_k=30,
    agent_type="openai-tools",
    verbose=True
)

# %%
response = agent_executor.invoke("Give me the breakdown of sales by city and country. Only include the 10 cities with the highest sales in descending order.")
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# Address, Customer, CustomerAddress, Product, ProductCategory, ProductDescription, ProductModel, ProductModelProductDescription, SalesOrderDetail, SalesOrderHeader
# Invoking: `sql_db_schema` with `{'table_names': 'Address'}`
#
#
#
# CREATE TABLE [SalesLT].[Address] (
# 	[AddressID] INTEGER NOT NULL IDENTITY(1,1),
# 	[AddressLine1] NVARCHAR(60) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[AddressLine2] NVARCHAR(60) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[City] NVARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PostalCode] NVARCHAR(15) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_Address_AddressID] PRIMARY KEY CLUSTERED ([AddressID])
# )
#
# /*
# 3 rows from Address table:
# AddressID	AddressLine1	AddressLine2	City	PostalCode	rowguid	ModifiedDate
# 9	8713 Yosemite Ct.	None	Bothell	98011	268af621-76d7-4c78-9441-144fd139821a	2006-07-01 00:00:00
# 11	1318 Lasalle Street	None	Bothell	98011	981b3303-aca2-49c7-9a96-fb670785b269	2007-04-01 00:00:00
# 25	9178 Jumping St.	None	Dallas	75201	c8df3bd9-48f0-4654-a8dd-14a67a84d3c6	2006-09-01 00:00:00
# */
# Invoking: `sql_db_schema` with `{'table_names': 'SalesOrderHeader'}`
#
#
#
# CREATE TABLE [SalesLT].[SalesOrderHeader] (
# 	[SalesOrderID] INTEGER NOT NULL DEFAULT (NEXT VALUE FOR [SalesLT].[SalesOrderNumber]),
# 	[RevisionNumber] TINYINT NOT NULL DEFAULT ((0)),
# 	[OrderDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	[DueDate] DATETIME NOT NULL,
# 	[ShipDate] DATETIME NULL,
# 	[Status] TINYINT NOT NULL DEFAULT ((1)),
# 	[SalesOrderNumber] AS ((isnull(N'SO'+CONVERT([nvarchar](23),[SalesOrderID],(0)),N'*** ERROR ***'))) NOT NULL,
# 	[CustomerID] INTEGER NOT NULL,
# 	[ShipToAddressID] INTEGER NULL,
# 	[BillToAddressID] INTEGER NULL,
# 	[ShipMethod] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CreditCardApprovalCode] VARCHAR(15) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SubTotal] MONEY NOT NULL DEFAULT ((0.00)),
# 	[TaxAmt] MONEY NOT NULL DEFAULT ((0.00)),
# 	[Freight] MONEY NOT NULL DEFAULT ((0.00)),
# 	[TotalDue] AS ((isnull(([SubTotal]+[TaxAmt])+[Freight],(0)))) NOT NULL,
# 	[Comment] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_SalesOrderHeader_SalesOrderID] PRIMARY KEY CLUSTERED ([SalesOrderID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Address_BillTo_AddressID] FOREIGN KEY([BillToAddressID]) REFERENCES [SalesLT].[Address] ([AddressID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Address_ShipTo_AddressID] FOREIGN KEY([ShipToAddressID]) REFERENCES [SalesLT].[Address] ([AddressID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Customer_CustomerID] FOREIGN KEY([CustomerID]) REFERENCES [SalesLT].[Customer] ([CustomerID])
# )
#
# /*
# 3 rows from SalesOrderHeader table:
# SalesOrderID	RevisionNumber	OrderDate	DueDate	ShipDate	Status	SalesOrderNumber	CustomerID	ShipToAddressID	BillToAddressID	ShipMethod	CreditCardApprovalCode	SubTotal	TaxAmt	Freight	TotalDue	Comment	rowguid	ModifiedDate
# 71774	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71774	29847	1092	1092	CARGO TRANSPORT 5	None	880.3484	70.4279	22.0087	972.7850	None	89e42cdc-8506-48a2-b89b-eb3e64e3554e	2008-06-08 00:00:00
# 71776	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71776	30072	640	640	CARGO TRANSPORT 5	None	78.8100	6.3048	1.9703	87.0851	None	8a3448c5-e677-4158-a29b-dd33069be0b0	2008-06-08 00:00:00
# 71780	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71780	30113	653	653	CARGO TRANSPORT 5	None	38418.6895	3073.4952	960.4672	42452.6519	None	a47665d2-7ac9-4cf3-8a8b-2a3883554284	2008-06-08 00:00:00
# */
# Invoking: `sql_db_schema` with `{'table_names': 'Customer'}`
#
#
#
# CREATE TABLE [SalesLT].[Customer] (
# 	[CustomerID] INTEGER NOT NULL IDENTITY(1,1),
# 	[Title] NVARCHAR(8) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Suffix] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CompanyName] NVARCHAR(128) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SalesPerson] NVARCHAR(256) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EmailAddress] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PasswordHash] VARCHAR(128) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PasswordSalt] VARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_Customer_CustomerID] PRIMARY KEY CLUSTERED ([CustomerID])
# )
#
# /*
# 3 rows from Customer table:
# CustomerID	Title	Suffix	CompanyName	SalesPerson	EmailAddress	PasswordHash	PasswordSalt	rowguid	ModifiedDate
# 1	Mr.	None	A Bike Store	adventure-works\pamela0	orlando0@adventure-works.com	L/Rlwxzp4w7RWmEgXX+/A7cXaePEPcp+KwQhl2fJL7w=	1KjXYs4=	3f5ae95e-b87d-4aed-95b4-c3797afcb74f	2005-08-01 00:00:00
# 2	Mr.	None	Progressive Sports	adventure-works\david8	keith0@adventure-works.com	YPdtRdvqeAhj6wyxEsFdshBDNXxkCXn+CRgbvJItknw=	fs1ZGhY=	e552f657-a9af-4a7d-a645-c429d6e02491	2006-08-01 00:00:00
# 3	Ms.	None	Advanced Bike Components	adventure-works\jillian0	donna0@adventure-works.com	LNoK27abGQo48gGue3EBV/UrlYSToV0/s87dCRV7uJk=	YTNH5Rw=	130774b1-db21-4ef3-98c8-c104bcd6ed6d	2005-09-01 00:00:00
# */
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT \n    a.City, \n    SUM(soh.TotalDue) AS TotalSales\nFROM \n    SalesLT.SalesOrderHeader AS soh\nJOIN \n    SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID\nGROUP BY \n    a.City\nORDER BY \n    TotalSales DESC\nLIMIT 10;'}`
# responded: To get the breakdown of sales by city and country, I will need to join the `SalesOrderHeader`, `Address`, and `Customer` tables. The relevant columns for the query will be the city from the `Address` table and the total sales amount from the `SalesOrderHeader` table.
#
# Here's the plan for the query:
# 1. Join `SalesOrderHeader` with `Address` on the `ShipToAddressID`.
# 2. Group by city and sum the `TotalDue` to get the total sales for each city.
# 3. Order the results by total sales in descending order.
# 4. Limit the results to the top 10 cities.
#
# Now, I will construct the SQL query.
#
# ```sql
# SELECT
#     a.City,
#     SUM(soh.TotalDue) AS TotalSales
# FROM
#     SalesLT.SalesOrderHeader AS soh
# JOIN
#     SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID
# GROUP BY
#     a.City
# ORDER BY
#     TotalSales DESC
# LIMIT 10;
# ```
#
# I will check this query for correctness before executing it.
#
# ```sql
# SELECT
#     a.City,
#     SUM(soh.TotalDue) AS TotalSales
# FROM
#     SalesLT.SalesOrderHeader AS soh
# JOIN
#     SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID
# GROUP BY
#     a.City
# ORDER BY
#     TotalSales DESC
# OFFSET 0 ROWS FETCH NEXT 10 ROWS ONLY;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT \n    a.City, \n    SUM(soh.TotalDue) AS TotalSales\nFROM \n    SalesLT.SalesOrderHeader AS soh\nJOIN \n    SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID\nGROUP BY \n    a.City\nORDER BY \n    TotalSales DESC\nOFFSET 0 ROWS FETCH NEXT 10 ROWS ONLY;'}`
#
#
# [('London', Decimal('206736.1667')), ('Woolston', Decimal('119960.8240')), ('Union City', Decimal('92663.5609')), ('Liverpool', Decimal('86222.8072')), ('Fullerton', Decimal('81834.9826')), ('Gloucestershire', Decimal('70698.9922')), ('Sherman Oaks', Decimal('63686.2708')), ('Cerritos', Decimal('45992.3665')), ('Van Nuys', Decimal('43962.7901')), ('West Sussex', Decimal('42452.6519'))]Here is the breakdown of sales by city for the top 10 cities with the highest sales:
#
# 1. **London**: $206,736.17
# 2. **Woolston**: $119,960.82
# 3. **Union City**: $92,663.56
# 4. **Liverpool**: $86,222.81
# 5. **Fullerton**: $81,834.98
# 6. **Gloucestershire**: $70,698.99
# 7. **Sherman Oaks**: $63,686.27
# 8. **Cerritos**: $45,992.37
# 9. **Van Nuys**: $43,962.79
# 10. **West Sussex**: $42,452.65
#
# These figures represent the total sales for each city.
#
# > Finished chain.

# %%
response = agent_executor.invoke("Dá-me as vendas por cidade e país. Inclui apenas as 10 cidades com as vendas mais altas por ordem decrescente.")
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# Address, Customer, CustomerAddress, Product, ProductCategory, ProductDescription, ProductModel, ProductModelProductDescription, SalesOrderDetail, SalesOrderHeader
# Invoking: `sql_db_schema` with `{'table_names': 'Address'}`
#
#
#
# CREATE TABLE [SalesLT].[Address] (
# 	[AddressID] INTEGER NOT NULL IDENTITY(1,1),
# 	[AddressLine1] NVARCHAR(60) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[AddressLine2] NVARCHAR(60) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[City] NVARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PostalCode] NVARCHAR(15) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_Address_AddressID] PRIMARY KEY CLUSTERED ([AddressID])
# )
#
# /*
# 3 rows from Address table:
# AddressID	AddressLine1	AddressLine2	City	PostalCode	rowguid	ModifiedDate
# 9	8713 Yosemite Ct.	None	Bothell	98011	268af621-76d7-4c78-9441-144fd139821a	2006-07-01 00:00:00
# 11	1318 Lasalle Street	None	Bothell	98011	981b3303-aca2-49c7-9a96-fb670785b269	2007-04-01 00:00:00
# 25	9178 Jumping St.	None	Dallas	75201	c8df3bd9-48f0-4654-a8dd-14a67a84d3c6	2006-09-01 00:00:00
# */
# Invoking: `sql_db_schema` with `{'table_names': 'SalesOrderHeader'}`
#
#
#
# CREATE TABLE [SalesLT].[SalesOrderHeader] (
# 	[SalesOrderID] INTEGER NOT NULL DEFAULT (NEXT VALUE FOR [SalesLT].[SalesOrderNumber]),
# 	[RevisionNumber] TINYINT NOT NULL DEFAULT ((0)),
# 	[OrderDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	[DueDate] DATETIME NOT NULL,
# 	[ShipDate] DATETIME NULL,
# 	[Status] TINYINT NOT NULL DEFAULT ((1)),
# 	[SalesOrderNumber] AS ((isnull(N'SO'+CONVERT([nvarchar](23),[SalesOrderID],(0)),N'*** ERROR ***'))) NOT NULL,
# 	[CustomerID] INTEGER NOT NULL,
# 	[ShipToAddressID] INTEGER NULL,
# 	[BillToAddressID] INTEGER NULL,
# 	[ShipMethod] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CreditCardApprovalCode] VARCHAR(15) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SubTotal] MONEY NOT NULL DEFAULT ((0.00)),
# 	[TaxAmt] MONEY NOT NULL DEFAULT ((0.00)),
# 	[Freight] MONEY NOT NULL DEFAULT ((0.00)),
# 	[TotalDue] AS ((isnull(([SubTotal]+[TaxAmt])+[Freight],(0)))) NOT NULL,
# 	[Comment] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_SalesOrderHeader_SalesOrderID] PRIMARY KEY CLUSTERED ([SalesOrderID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Address_BillTo_AddressID] FOREIGN KEY([BillToAddressID]) REFERENCES [SalesLT].[Address] ([AddressID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Address_ShipTo_AddressID] FOREIGN KEY([ShipToAddressID]) REFERENCES [SalesLT].[Address] ([AddressID]),
# 	CONSTRAINT [FK_SalesOrderHeader_Customer_CustomerID] FOREIGN KEY([CustomerID]) REFERENCES [SalesLT].[Customer] ([CustomerID])
# )
#
# /*
# 3 rows from SalesOrderHeader table:
# SalesOrderID	RevisionNumber	OrderDate	DueDate	ShipDate	Status	SalesOrderNumber	CustomerID	ShipToAddressID	BillToAddressID	ShipMethod	CreditCardApprovalCode	SubTotal	TaxAmt	Freight	TotalDue	Comment	rowguid	ModifiedDate
# 71774	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71774	29847	1092	1092	CARGO TRANSPORT 5	None	880.3484	70.4279	22.0087	972.7850	None	89e42cdc-8506-48a2-b89b-eb3e64e3554e	2008-06-08 00:00:00
# 71776	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71776	30072	640	640	CARGO TRANSPORT 5	None	78.8100	6.3048	1.9703	87.0851	None	8a3448c5-e677-4158-a29b-dd33069be0b0	2008-06-08 00:00:00
# 71780	2	2008-06-01 00:00:00	2008-06-13 00:00:00	2008-06-08 00:00:00	5	SO71780	30113	653	653	CARGO TRANSPORT 5	None	38418.6895	3073.4952	960.4672	42452.6519	None	a47665d2-7ac9-4cf3-8a8b-2a3883554284	2008-06-08 00:00:00
# */
# Invoking: `sql_db_schema` with `{'table_names': 'SalesOrderDetail'}`
#
#
#
# CREATE TABLE [SalesLT].[SalesOrderDetail] (
# 	[SalesOrderID] INTEGER NOT NULL,
# 	[SalesOrderDetailID] INTEGER NOT NULL IDENTITY(1,1),
# 	[OrderQty] SMALLINT NOT NULL,
# 	[ProductID] INTEGER NOT NULL,
# 	[UnitPrice] MONEY NOT NULL,
# 	[UnitPriceDiscount] MONEY NOT NULL DEFAULT ((0.0)),
# 	[LineTotal] AS ((isnull(([UnitPrice]*((1.0)-[UnitPriceDiscount]))*[OrderQty],(0.0)))) NOT NULL,
# 	rowguid UNIQUEIDENTIFIER NOT NULL DEFAULT (newid()),
# 	[ModifiedDate] DATETIME NOT NULL DEFAULT (getdate()),
# 	CONSTRAINT [PK_SalesOrderDetail_SalesOrderID_SalesOrderDetailID] PRIMARY KEY CLUSTERED ([SalesOrderID], [SalesOrderDetailID]),
# 	CONSTRAINT [FK_SalesOrderDetail_Product_ProductID] FOREIGN KEY([ProductID]) REFERENCES [SalesLT].[Product] ([ProductID]),
# 	CONSTRAINT [FK_SalesOrderDetail_SalesOrderHeader_SalesOrderID] FOREIGN KEY([SalesOrderID]) REFERENCES [SalesLT].[SalesOrderHeader] ([SalesOrderID]) ON DELETE CASCADE
# )
#
# /*
# 3 rows from SalesOrderDetail table:
# SalesOrderID	SalesOrderDetailID	OrderQty	ProductID	UnitPrice	UnitPriceDiscount	LineTotal	rowguid	ModifiedDate
# 71774	110562	1	836	356.8980	0.0000	356.898000	e3a1994c-7a68-4ce8-96a3-77fdd3bbd730	2008-06-01 00:00:00
# 71774	110563	1	822	356.8980	0.0000	356.898000	5c77f557-fdb6-43ba-90b9-9a7aec55ca32	2008-06-01 00:00:00
# 71776	110567	1	907	63.9000	0.0000	63.900000	6dbfe398-d15d-425e-aa58-88178fe360e5	2008-06-01 00:00:00
# */
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT \n    a.City, \n    SUM(soh.TotalDue) AS TotalSales\nFROM \n    SalesLT.SalesOrderHeader AS soh\nJOIN \n    SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID\nGROUP BY \n    a.City\nORDER BY \n    TotalSales DESC\nLIMIT 10;'}`
# responded: To get the sales by city and country, I will need to join the `SalesOrderHeader`, `SalesOrderDetail`, and `Address` tables. The relevant columns for the query will include the city from the `Address` table and the total sales amount from the `SalesOrderHeader` table.
#
# I will construct a query that sums the total sales for each city, groups the results by city, and orders them in descending order to get the top 10 cities with the highest sales.
#
# Here is the query I will use:
#
# ```sql
# SELECT
#     a.City,
#     SUM(soh.TotalDue) AS TotalSales
# FROM
#     SalesLT.SalesOrderHeader AS soh
# JOIN
#     SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID
# GROUP BY
#     a.City
# ORDER BY
#     TotalSales DESC
# LIMIT 10;
# ```
#
# Now, I will check this query for correctness before executing it.
#
# ```sql
# SELECT
#     a.City,
#     SUM(soh.TotalDue) AS TotalSales
# FROM
#     SalesLT.SalesOrderHeader AS soh
# JOIN
#     SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID
# GROUP BY
#     a.City
# ORDER BY
#     TotalSales DESC
# OFFSET 0 ROWS FETCH NEXT 10 ROWS ONLY;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT \n    a.City, \n    SUM(soh.TotalDue) AS TotalSales\nFROM \n    SalesLT.SalesOrderHeader AS soh\nJOIN \n    SalesLT.Address AS a ON soh.ShipToAddressID = a.AddressID\nGROUP BY \n    a.City\nORDER BY \n    TotalSales DESC\nOFFSET 0 ROWS FETCH NEXT 10 ROWS ONLY;'}`
#
#
# [('London', Decimal('206736.1667')), ('Woolston', Decimal('119960.8240')), ('Union City', Decimal('92663.5609')), ('Liverpool', Decimal('86222.8072')), ('Fullerton', Decimal('81834.9826')), ('Gloucestershire', Decimal('70698.9922')), ('Sherman Oaks', Decimal('63686.2708')), ('Cerritos', Decimal('45992.3665')), ('Van Nuys', Decimal('43962.7901')), ('West Sussex', Decimal('42452.6519'))]As vendas por cidade, incluindo as 10 cidades com as vendas mais altas, são as seguintes:
#
# 1. **London**: 206736.17
# 2. **Woolston**: 119960.82
# 3. **Union City**: 92663.56
# 4. **Liverpool**: 86222.81
# 5. **Fullerton**: 81834.98
# 6. **Gloucestershire**: 70698.99
# 7. **Sherman Oaks**: 63686.27
# 8. **Cerritos**: 45992.37
# 9. **Van Nuys**: 43962.79
# 10. **West Sussex**: 42452.65
#
# Essas cidades estão ordenadas por suas vendas totais em ordem decrescente.
#
# > Finished chain.
